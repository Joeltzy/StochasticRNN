# %%
import math
import torch
import torch.nn as nn
import torch.utils
import torch.utils.data
from torchvision import datasets, transforms
import matplotlib.pyplot as plt 
"""implementation of the Variational Recurrent
Neural Network (VRNN) from https://arxiv.org/abs/1506.02216
using unimodal isotropic gaussian distributions for 
inference, prior, and generating models."""
# Out:
# 'implementation of the Variational Recurrent\nNeural Network (VRNN) from https://arxiv.org/abs/1506.02216\nusing unimodal isotropic gaussian distributions for \ninference, prior, and generating models.'

# %%
import torchvision.transforms as transforms
from torch.autograd import Variable
from ta import *
from pandas import DataFrame
from pandas import concat
import math
from numpy import reshape
from sklearn.preprocessing import MinMaxScaler
from numpy import array

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
"""ACF PLOT/ADF Test, Check Stationality"""
train_data = pd.read_csv("S&P500_train.csv") #Data from 1st Jan 2009 to 31 dec 2017
y_train = train_data['Volume']
scaler = MinMaxScaler()
y_train = array(y_train)
y_train = y_train.reshape(y_train.shape[0], 1)
y_train = scaler.fit_transform(y_train)
y_train_arr = []
for i in range (0, len(y_train)):
    y_train_arr.append(y_train[i][0])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
import seaborn as sns
sns.set()

# %%
plt.plot(train_data['Volume'])

# %%
plt.title('Autocorrelation of Volume in Train Dataset')
plt.xlabel('Lags')
fig = plot_acf(y_train, lags=40)
fig.savefig('ACF_1.png')

# %%
"""Plot of train volume"""
plt.title('Plot of Volume in Train Dataset')
plt.xlabel('Time')
plt.ylabel('Standardized Volume')
plt.plot(y_train)
plt.savefig('train_volume.png')

# %%
"""ADF test for stationality"""
from statsmodels.tsa.stattools import adfuller
"""Class to test for stationality"""
class StationarityTests:
    def __init__(self, significance=.05):
        self.SignificanceLevel = significance
        self.pValue = None
        self.isStationary = None
    def ADF_Stationarity_Test(self, timeseries, printResults = True):

        #Dickey-Fuller test:
        adfTest = adfuller(timeseries, autolag='AIC')
        
        self.pValue = adfTest[1]
        
        if (self.pValue<self.SignificanceLevel):
            self.isStationary = True
        else:
            self.isStationary = False
        
        if printResults:
            dfResults = pd.Series(adfTest[0:4], index=['ADF Test Statistic','P-Value','# Lags Used','# Observations Used'])

            #Add Critical Values
            for key,value in adfTest[4].items():
                dfResults['Critical Value (%s)'%key] = value

            print('Augmented Dickey-Fuller Test Results:')
            print(dfResults)      
sTest = StationarityTests()    
sTest.ADF_Stationarity_Test(y_train_arr, printResults = True) 
print("Is the time series stationary? {0}".format(sTest.isStationary))
# Out:
# Augmented Dickey-Fuller Test Results:
# ADF Test Statistic        -2.588877
# P-Value                    0.095318
# # Lags Used               21.000000
# # Observations Used     2242.000000
# Critical Value (1%)       -3.433270
# Critical Value (5%)       -2.862830
# Critical Value (10%)      -2.567457
# dtype: float64
# Is the time series stationary? False

# %%
"""Check if diff=1 will make it stationary"""
y_train_df = pd.DataFrame(y_train)
y_train_df = y_train_df.diff()
y_train_diff_arr = np.array(y_train_df[0])
y_train_diff_arr = y_train_diff_arr[~np.isnan(y_train_diff_arr)]
sTest.ADF_Stationarity_Test(y_train_diff_arr, printResults = True) 
print("Is the time series stationary? {0}".format(sTest.isStationary)) # yes it is stationary now
# Out:
# Augmented Dickey-Fuller Test Results:
# ADF Test Statistic     -1.406571e+01
# P-Value                 3.001401e-26
# # Lags Used             2.700000e+01
# # Observations Used     2.235000e+03
# Critical Value (1%)    -3.433279e+00
# Critical Value (5%)    -2.862834e+00
# Critical Value (10%)   -2.567459e+00
# dtype: float64
# Is the time series stationary? True

# %%
"""ACF Plot of Stationary TS (Volume)"""
fig = plot_acf(y_train_diff_arr, lags=40)
plt.title('Autocorrelation of Volume in Train Dataset')
plt.xlabel('Lags')
fig.savefig('ACF_2.png')

# %%
"""Plot of train diff volume"""
plt.title('Plot of Volume (Lag 1) in Train Dataset')
plt.xlabel('Time')
plt.ylabel('Standardized Volume')
plt.plot(y_train_diff_arr)
plt.savefig('train_diff_volume.png')

# %%
train_data = pd.read_csv("S&P500_train.csv") #Data from 1st Jan 2009 to 31 dec 2017
test_data = pd.read_csv("S&P500_test.csv") #Data from 1st Jan 2018 to 31 Dec 2018
train_val = add_all_ta_features(train_data, "Open Price", "High Price", "Low Price", "Close Price", "Volume", fillna=True)
test_val = add_all_ta_features(test_data, "Open Price", "High Price", "Low Price", "Close Price", "Volume", fillna=True)

trainset_val = train_val.drop(['Date'], axis=1)
testset_val = test_val.drop(['Date'], axis=1)

train_val = trainset_val.diff() #diff lag=1, to make it stationary
train_val = trainset_val.dropna() #remove NA values from diff
test_val = testset_val.diff() #diff lag=1, to make it stationary
test_val = testset_val.dropna() #remove NA values from diff

train_val = train_val.iloc[:,0:28] # selecting the first 28 columns
test_val = test_val.iloc[:,0:28] # selecting the first 28 columns
data_headers = train_val

train_y_values = train_val['Volume']
test_y_values = test_val['Volume']

scaler = MinMaxScaler()

TIME_STEP = 29  # rnn time step / image height  

train_val = scaler.fit_transform(train_val)
train_x = series_to_supervised(train_val, n_in=TIME_STEP-1, n_out=-1)
train_x = train_x.values
train_x = train_x[:, : ]
train_x = reshape(train_x, (train_x.shape[0], 1, TIME_STEP-1, 28))
train_x = torch.from_numpy(train_x)

train_y = array(train_y_values)
train_y = train_y.reshape(train_y.shape[0], 1)
train_y = scaler.fit_transform(train_y)
train_y = series_to_supervised(train_y, n_in=TIME_STEP-2, n_out=1)
train_y = train_y.iloc[1:]
train_y = train_y.values
train_y = train_y[:, : ]
train_y = reshape(train_y, (train_y.shape[0], 1, TIME_STEP-1, 1))
train_y = torch.from_numpy(train_y)


test_val = scaler.fit_transform(test_val)
test_x = series_to_supervised(test_val, n_in=TIME_STEP-1, n_out=-1)
test_x = test_x.values
test_x = test_x[:, : ]
test_x = reshape(test_x, (test_x.shape[0], 1, TIME_STEP-1, 28))
test_x = torch.from_numpy(test_x)

test_y = array(test_y_values)
test_y = test_y.reshape(test_y.shape[0], 1)
test_y = scaler.fit_transform(test_y)
test_y = series_to_supervised(test_y, n_in=TIME_STEP-2, n_out=1)
test_y = test_y.iloc[1:]
test_y = test_y.values
test_y = test_y[:, : ]
test_y = reshape(test_y, (test_y.shape[0], 1, TIME_STEP-1, 1))
test_y = torch.from_numpy(test_y)

train_x = train_x.double()
train_y = train_y.double()
test_x = test_x.double()
test_y = test_y.double()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ta/trend.py:170: RuntimeWarning: divide by zero encountered in double_scalars
#   dip[i] = 100 * (dip_mio[i]/trs[i])
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ta/trend.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (dip_mio[i]/trs[i])
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ta/trend.py:174: RuntimeWarning: divide by zero encountered in double_scalars
#   din[i] = 100 * (din_mio[i]/trs[i])
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ta/trend.py:174: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (din_mio[i]/trs[i])
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ta/trend.py:176: RuntimeWarning: invalid value encountered in subtract
#   dx = 100 * np.abs((dip - din) / (dip + din))
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
train_dataset = torch.utils.data.TensorDataset(train_x, train_y)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=False)

test_dataset = torch.utils.data.TensorDataset(test_x, test_y)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=147, shuffle=False)
"""Data Preparation"""
# Out:
# 'Data Preparation'

# %%
print(train_x.shape, train_y.shape)
print(test_x.shape, test_y.shape)
"""Shape of train and test set"""
# Out:
# torch.Size([2236, 1, 28, 28]) torch.Size([2236, 1, 28, 1])
# torch.Size([224, 1, 28, 28]) torch.Size([224, 1, 28, 1])
# 'Shape of train and test set'

# %%
from scipy.stats import kurtosis, skew
print( kurtosis(temp.dropna()))
print( 'excess kurtosis of normal distribution (should be 0): {}'.format( kurtosis(temp.dropna()) ))
print( 'skewness of normal distribution (should be 0): {}'.format( skew(trainset_val['Volume']) ))
# Out:
# 5.2468955580170675
# excess kurtosis of normal distribution (should be 0): 5.2468955580170675
# skewness of normal distribution (should be 0): 1.6282230974562641

# %%
temp = trainset_val['Close Price'].pct_change()
fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
ax1.plot(temp)
ax1.set_xlabel("Date")
ax1.set_ylabel("Percent")
ax1.set_title("Netflix daily returns data")
plt.show()

# %%
# Out:
# 0            NaN
# 1      -0.004668
# 2       0.007817
# 3      -0.030010
# 4       0.003397
#           ...
# 2259   -0.000458
# 2260   -0.001058
# 2261    0.000791
# 2262    0.001834
# 2263   -0.005183
# Name: Close Price, Length: 2264, dtype: float64

# %%
# iterating the columns 
for col in data_headers.columns: 
    print(col)
# Out:
# Open Price
# Close Price
# High Price
# Low Price
# Volume
# volume_adi
# volume_obv
# volume_cmf
# volume_fi
# volume_em
# volume_vpt
# volume_nvi
# volatility_atr
# volatility_bbh
# volatility_bbl
# volatility_bbm
# volatility_bbhi
# volatility_bbli
# volatility_kcc
# volatility_kch
# volatility_kcl
# volatility_kchi
# volatility_kcli
# volatility_dch
# volatility_dcl
# volatility_dchi
# volatility_dcli
# trend_macd

# %%
class SRNN(nn.Module):
	def __init__(self, x_dim, h_dim, z_dim, n_layers, bias=False):
		super(SRNN, self).__init__()
		self.x_dim = x_dim
		self.h_dim = h_dim
		self.z_dim = z_dim
		self.n_layers = n_layers


		#encoder  x/u to z, input to latent variable, inference model
		self.enc = nn.Sequential(
			nn.Linear(h_dim, h_dim),
			nn.ReLU(),
			nn.Linear(h_dim, h_dim),
			nn.ReLU())
		self.enc_mean = nn.Linear(h_dim, z_dim)
		self.enc_std = nn.Sequential(
			nn.Linear(h_dim, z_dim),
			nn.Softplus())

		#prior transition of zt-1 to zt
		self.prior = nn.Sequential(
			nn.Linear(h_dim, h_dim),
			nn.ReLU())
		self.prior_mean = nn.Linear(h_dim, z_dim)
		self.prior_std = nn.Sequential(
			nn.Linear(h_dim, z_dim),
			nn.Softplus())

		#decoder from latent variable to output, from z to y
		self.dec = nn.Sequential(
			nn.Linear(h_dim + h_dim, h_dim),
			nn.ReLU(),
			nn.Linear(h_dim, h_dim),
			nn.ReLU())
		self.dec_std = nn.Sequential(
			nn.Linear(h_dim, x_dim),
			nn.Softplus())
		self.dec_mean = nn.Sequential(
			nn.Linear(h_dim, x_dim),
			nn.Sigmoid())

		#recurrence backward RNN, another RNN fn here for SRNN
# 		self.rnn = nn.GRU(h_dim + h_dim, h_dim, n_layers, bias)    
		self.rnn = nn.GRU(h_dim + 1, h_dim, n_layers, bias) # 1 is for y dim, cause concat h and y, h is 28 y is 1       
		self.hidden_state_rnn = nn.GRU(h_dim, h_dim, n_layers, bias)          
        

	def forward(self, x, y):
        #generative and inference model
		all_enc_mean, all_enc_std = [], [] #inference
		all_dec_mean, all_dec_std = [], [] 
		kld_loss = 0 #KL in ELBO
		nll_loss = 0 #-loglikihood in ELBO
            
		z_t_sampled = []
		z_t = torch.zeros(self.n_layers, x.size(1), self.h_dim)[-1] 
           
        # computing hidden state in list and x_t & y_t in list outside the loop
		h = torch.zeros(self.n_layers, x.size(1), self.h_dim)   
		h_list = []
		x_t_list = []  
		y_t_list = []
              
		for t in range(x.size(0)):
			x_t = x[t]  
			y_t = y[t]                   
			_, h = self.hidden_state_rnn(torch.cat([x_t], 1).unsqueeze(0), h)      
			y_t_list.append(y_t)             
			x_t_list.append(x_t)            
			h_list.append(h[-1])        
               
        #reversing hidden state list
		reversed_h = h_list
		reversed_h.reverse()
        
        #reversing y_t list
		reversed_y_t = y_t_list
		reversed_y_t.reverse()          
        
        #concat reverse h with reverse x_t
		concat_h_t_y_t_list = []         
 
		for t in range(x.size(0)): #x.size(0) == y.size(0) == 28           
			concat_h_t_y_t = torch.cat([reversed_y_t[t], reversed_h[t]], 1).unsqueeze(0) 
			concat_h_t_y_t_list.append(concat_h_t_y_t)     
            
        #compute reverse a_t
		a_t = torch.zeros(self.n_layers, x.size(1), self.h_dim)
		reversed_a_t_list = []
		for t in range(x.size(0)):    
			_, a_t = self.rnn(concat_h_t_y_t_list[t], a_t) #RNN new      
			reversed_a_t_list.append(a_t[-1])            
		reversed_a_t_list.reverse()        

		for t in range(x.size(0)):          
            
			#encoder
			enc_t = self.enc(reversed_a_t_list[t])
			enc_mean_t = self.enc_mean(enc_t)
			enc_std_t = self.enc_std(enc_t)    
    
			#sampling and reparameterization, sampling from infer network
			z_t = self._reparameterized_sample(enc_mean_t, enc_std_t) 
			z_t_sampled.append(z_t)             
            
			#prior #transition, 
			prior_t = self.prior(h_list[t])         
			prior_mean_t = self.prior_mean(prior_t)
			prior_std_t = self.prior_std(prior_t)
            
			#decoder #emission (generativemodel) 
			dec_t = self.dec(torch.cat([z_t, h_list[t]], 1))              
			dec_mean_t = self.dec_mean(dec_t)
			dec_std_t = self.dec_std(dec_t)

			#computing losses
			kld_loss += self._kld_gauss(enc_mean_t, enc_std_t, prior_mean_t, prior_std_t)          
			nll_loss += self._nll_bernoulli(dec_mean_t, y[t]) #change x[t] to y[t]

			all_enc_std.append(enc_std_t)
			all_enc_mean.append(enc_mean_t)
			all_dec_mean.append(dec_mean_t)
			all_dec_std.append(dec_std_t)  
            
		return kld_loss,nll_loss,(all_enc_mean, all_enc_std),(all_dec_mean, all_dec_std)
            

	def forecasting(self,x,step,y):
		all_enc_mean, all_enc_std = [], []
		all_dec_mean, all_dec_std = [], []
		z_t_sampled = []  
		z_t = torch.zeros(self.n_layers, x.size(1), self.h_dim)[-1]  
    
        # computing hidden state in list and x_t & y_t in list outside the loop
		h = torch.zeros(self.n_layers, x.size(1), self.h_dim)   
		h_list = []
		x_t_list = []
		y_t_list = []        
		for t in range(x.size(0)):        
			x_t = x[t]   
			y_t = y[t]               
			_, h = self.hidden_state_rnn(torch.cat([x_t], 1).unsqueeze(0), h)            
			x_t_list.append(x_t)
			y_t_list.append(y_t) 
			h_list.append(h[-1])
               
        #reversing hidden state list
		reversed_h = h_list
		reversed_h.reverse()
        
        #reversing y_t list
		reversed_y_t = y_t_list
		reversed_y_t.reverse()
        
#         #concat reverse h with reverse x_t
		concat_h_t_y_t_list = []      
		for t in range(x.size(0)):
			concat_h_t_y_t = torch.cat([reversed_y_t[t], reversed_h[t]], 1).unsqueeze(0) 
			concat_h_t_y_t_list.append(concat_h_t_y_t)
            
#         #compute reverse a_t   
		a_t = torch.zeros(self.n_layers, x.size(1), self.h_dim)
		reversed_a_t_list = []
		for t in range(x.size(0)):        
			_, a_t = self.rnn(concat_h_t_y_t_list[t], a_t) #RNN new         
			reversed_a_t_list.append(a_t[-1])             
		reversed_a_t_list.reverse()  

		for t in range(x.size(0)):      
			x_t = x[t] 

			#encoder   
			enc_t = self.enc(reversed_a_t_list[t])
			enc_mean_t = self.enc_mean(enc_t)
			enc_std_t = self.enc_std(enc_t)
            
			#prior
			prior_t = self.prior(h_list[t])   
			prior_mean_t = self.prior_mean(prior_t)
			prior_std_t = self.prior_std(prior_t)
        
			#sampling and reparameterization
			z_t = self._reparameterized_sample(enc_mean_t, enc_std_t)
			z_t_sampled.append(z_t)
            
			#decoder
			dec_t = self.dec(torch.cat([z_t, h_list[t]], 1))            
			dec_mean_t = self.dec_mean(dec_t)
			dec_std_t = self.dec_std(dec_t)
            
			all_enc_std.append(enc_std_t)
			all_enc_mean.append(enc_mean_t)
			all_dec_mean.append(dec_mean_t)
			all_dec_std.append(dec_std_t)  
    
    
		x_predict=[]
		for i in range(step):
			#prior 
			prior_t = self.prior(h_list[t]) 
			prior_mean_t = self.prior_mean(prior_t)
			prior_std_t = self.prior_std(prior_t)
            
			#sampling and reparameterization
			z_t = self._reparameterized_sample(enc_mean_t, enc_std_t)
			z_t_sampled.append(z_t)
            
			#decoder
			dec_t = self.dec(torch.cat([z_t, h_list[i]], 1))                                                               
			dec_mean_t = self.dec_mean(dec_t)
			dec_std_t = self.dec_std(dec_t)

			x_t = dec_mean_t  
			x_predict.append(dec_mean_t)           
                        
		return x_predict,z_t_sampled
            

	def reset_parameters(self, stdv=1e-1):
		for weight in self.parameters():
			weight.normal_(0, stdv)


	def _init_weights(self, stdv):
		pass


	def _reparameterized_sample(self, mean, std):
		"""using std to sample"""
		eps = torch.FloatTensor(std.size()).normal_()
		return eps.mul(std).add_(mean)


	def _kld_gauss(self, mean_1, std_1, mean_2, std_2):
		"""Using std to compute KLD"""

		kld_element =  (2 * torch.log(std_2) - 2 * torch.log(std_1) + 
			(std_1.pow(2) + (mean_1 - mean_2).pow(2)) /
			std_2.pow(2) - 1)
		return	0.5 * torch.sum(kld_element)


	def _nll_bernoulli(self, theta, x):
		return - torch.sum(x*torch.log(theta) + (1-x)*torch.log(1-theta))


	def _nll_gauss(self, mean, std, x):
		return  torch.sum(torch.log(std) + (x-mean).pow(2)/(2*std.pow(2)))

# %%
"""Storing NLL in arrays for plots"""
train_NLL = []
test_NLL = []

# %%
"""implementation of the Variational Recurrent
Neural Network (VRNN) from https://arxiv.org/abs/1506.02216
using unimodal isotropic gaussian distributions for 
inference, prior, and generating models."""


def train(epoch): # change model to take in x and y
	train_loss = 0
	for batch_idx, (data, b_y) in enumerate(train_loader):     
       
		data = data.float()        
		data = data.squeeze(1).transpose(0, 1)   #data 3 dim no need to have squeeze , squeeze the first dim out (1)         
		data = (data - data.min().item()) / (data.max().item() - data.min().item())

		b_y = b_y.float()
		b_y = b_y.squeeze(1).transpose(0, 1)       
		b_y = (b_y - b_y.min().item()) / (b_y.max().item() - b_y.min().item())
    
		#forward + backward + optimize
		optimizer.zero_grad()          
		kld_loss,nll_loss,_,_= model(data, b_y)
		loss = kld_loss + nll_loss
		loss.backward()
		optimizer.step()

		#grad norm clipping, only in pytorch version >= 1.10
		nn.utils.clip_grad_norm_(model.parameters(), clip)
            
		#printing
		if batch_idx % print_every == 0:
			print('Train Epoch: {} [{}/{} ({:.0f}%)]\t KLD Loss: {:.6f} \t NLL Loss: {:.6f}'.format(
				epoch, batch_idx * len(data), len(train_loader.dataset),
				100. * batch_idx / len(train_loader),
				kld_loss.item() / batch_size,
				nll_loss.item()/ batch_size))
			train_NLL.append(nll_loss.item()/ batch_size)
                
		train_loss += loss.item()
	print('====> Epoch: {} Average loss: {:.4f}'.format(
		epoch, train_loss / len(train_loader.dataset)))
    

def test(epoch):
	"""uses test data to evaluate 
	likelihood of the model"""

	mean_kld_loss, mean_nll_loss = 0, 0
	for i, (data, b_y) in enumerate(test_loader):        
		data = data.float()
		data = data.squeeze(1).transpose(0, 1)
		data = (data - data.min().item()) / (data.max().item() - data.min().item())
     
		b_y = b_y.float()
		b_y = b_y.squeeze(1).transpose(0, 1)       
		b_y = (b_y - b_y.min().item()) / (b_y.max().item() - b_y.min().item())

		kld_loss, nll_loss,(ecoder_z_mean,ecoder_z_std), (decoder_z_mean,decoder_z_std) = model(data, b_y)
		mean_kld_loss += kld_loss.item()
		mean_nll_loss += nll_loss.item()
		x_predict,z_sampled = model.forecasting(data,1,b_y) #number here is number of time steps
# 		print(b_y.size())
	mean_kld_loss /= len(test_loader.dataset)
	mean_nll_loss /= len(test_loader.dataset)

	print('====> Test set loss: KLD Loss = {:.4f}, NLL Loss = {:.4f} '.format(
		mean_kld_loss, mean_nll_loss))
	test_NLL.append(mean_nll_loss)    
# 	print(np.shape(x_predict))
# 	print(len(x_predict[0]))   
# 	print(x_predict) 
    
	return x_predict,z_sampled,torch.stack(ecoder_z_mean),torch.stack(ecoder_z_std),torch.stack(decoder_z_mean),torch.stack(decoder_z_std)

# %%
#hyperparameters
x_dim = 28
h_dim = 28
z_dim = 28

n_layers =  1
n_epochs = 20
clip = 10
learning_rate = 1e-3
batch_size = 128
seed = 128
print_every = 100
save_every = 2

prediction = []

#manual seed
torch.manual_seed(seed)
plt.ion()

#init model + optimizer + datasets

model = SRNN(x_dim, h_dim, z_dim, n_layers)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

for epoch in range(1, n_epochs + 1):
	#training + testing
	train(epoch)
	x_predict,z_sampled,ecoder_z_mean,ecoder_z_std,decoder_z_mean,decoder_z_std = test(epoch)
# 	print(len(x_predict[0]))
# 	if epoch == n_epochs:
# 		for index in range(0,195):        
# 			prediction.append(x_predict[0][index][27])      #always 27 cause taking last entry
# 	else:
# 		continue
# Out:
# Train Epoch: 1 [0/2235 (0%)]	 KLD Loss: 8.985008 	 NLL Loss: 135.493805
# ====> Epoch: 1 Average loss: 549.3516
# ====> Test set loss: KLD Loss = 0.1812, NLL Loss = 543.0974
# Train Epoch: 2 [0/2235 (0%)]	 KLD Loss: 0.038022 	 NLL Loss: 136.314392
# ====> Epoch: 2 Average loss: 543.7449
# ====> Test set loss: KLD Loss = 0.1098, NLL Loss = 542.4481
# Train Epoch: 3 [0/2235 (0%)]	 KLD Loss: 0.017135 	 NLL Loss: 136.631027
# ====> Epoch: 3 Average loss: 543.6023
# ====> Test set loss: KLD Loss = 0.0842, NLL Loss = 542.2317
# Train Epoch: 4 [0/2235 (0%)]	 KLD Loss: 0.011083 	 NLL Loss: 136.743225
# ====> Epoch: 4 Average loss: 543.5558
# ====> Test set loss: KLD Loss = 0.0693, NLL Loss = 542.1640
# Train Epoch: 5 [0/2235 (0%)]	 KLD Loss: 0.008225 	 NLL Loss: 136.795090
# ====> Epoch: 5 Average loss: 543.5302
# ====> Test set loss: KLD Loss = 0.0595, NLL Loss = 542.1335
# Train Epoch: 6 [0/2235 (0%)]	 KLD Loss: 0.006557 	 NLL Loss: 136.802094
# ====> Epoch: 6 Average loss: 543.5113
# ====> Test set loss: KLD Loss = 0.0503, NLL Loss = 542.1147
# Train Epoch: 7 [0/2235 (0%)]	 KLD Loss: 0.006124 	 NLL Loss: 136.821381
# ====> Epoch: 7 Average loss: 543.5008
# ====> Test set loss: KLD Loss = 0.0490, NLL Loss = 542.1139
# Train Epoch: 8 [0/2235 (0%)]	 KLD Loss: 0.004621 	 NLL Loss: 136.819641
# ====> Epoch: 8 Average loss: 543.4922
# ====> Test set loss: KLD Loss = 0.0462, NLL Loss = 542.1127
# Train Epoch: 9 [0/2235 (0%)]	 KLD Loss: 0.004043 	 NLL Loss: 136.821014
# ====> Epoch: 9 Average loss: 543.4839
# ====> Test set loss: KLD Loss = 0.0458, NLL Loss = 542.1174
# Train Epoch: 10 [0/2235 (0%)]	 KLD Loss: 0.003527 	 NLL Loss: 136.807587
# ====> Epoch: 10 Average loss: 543.4734
# ====> Test set loss: KLD Loss = 0.0444, NLL Loss = 542.1177
# Train Epoch: 11 [0/2235 (0%)]	 KLD Loss: 0.003171 	 NLL Loss: 136.814987
# ====> Epoch: 11 Average loss: 543.4706
# ====> Test set loss: KLD Loss = 0.0455, NLL Loss = 542.1214
# Train Epoch: 12 [0/2235 (0%)]	 KLD Loss: 0.002649 	 NLL Loss: 136.811600
# ====> Epoch: 12 Average loss: 543.4634
# ====> Test set loss: KLD Loss = 0.0458, NLL Loss = 542.1193
# Train Epoch: 13 [0/2235 (0%)]	 KLD Loss: 0.002291 	 NLL Loss: 136.810104
# ====> Epoch: 13 Average loss: 543.4577
# ====> Test set loss: KLD Loss = 0.0435, NLL Loss = 542.1203
# Train Epoch: 14 [0/2235 (0%)]	 KLD Loss: 0.002062 	 NLL Loss: 136.810028
# ====> Epoch: 14 Average loss: 543.4554
# ====> Test set loss: KLD Loss = 0.0451, NLL Loss = 542.1242
# Train Epoch: 15 [0/2235 (0%)]	 KLD Loss: 0.001811 	 NLL Loss: 136.808029
# ====> Epoch: 15 Average loss: 543.4523
# ====> Test set loss: KLD Loss = 0.0449, NLL Loss = 542.1311
# Train Epoch: 16 [0/2235 (0%)]	 KLD Loss: 0.001657 	 NLL Loss: 136.803635
# ====> Epoch: 16 Average loss: 543.4467
# ====> Test set loss: KLD Loss = 0.0445, NLL Loss = 542.1273
# Train Epoch: 17 [0/2235 (0%)]	 KLD Loss: 0.001557 	 NLL Loss: 136.805099
# ====> Epoch: 17 Average loss: 543.4442
# ====> Test set loss: KLD Loss = 0.0448, NLL Loss = 542.1267
# Train Epoch: 18 [0/2235 (0%)]	 KLD Loss: 0.001447 	 NLL Loss: 136.804169
# ====> Epoch: 18 Average loss: 543.4423
# ====> Test set loss: KLD Loss = 0.0436, NLL Loss = 542.1297
# Train Epoch: 19 [0/2235 (0%)]	 KLD Loss: 0.001363 	 NLL Loss: 136.801300
# ====> Epoch: 19 Average loss: 543.4389
# ====> Test set loss: KLD Loss = 0.0433, NLL Loss = 542.1282
# Train Epoch: 20 [0/2235 (0%)]	 KLD Loss: 0.001280 	 NLL Loss: 136.803802
# ====> Epoch: 20 Average loss: 543.4373
# ====> Test set loss: KLD Loss = 0.0422, NLL Loss = 542.1337

# %%
len(train_NLL)
# Out:
# 20

# %%
len(test_NLL)
# Out:
# 20

# %%
"""Plot of train diff volume"""
plt.title('Plot of Volume (Lag 1) in Train Dataset')
plt.xlabel('Time')
plt.ylabel('Standardized Volume')
plt.plot(y_train_diff_arr)
plt.savefig('train_diff_volume.png')

# %%
"""Plot of train and test NLL (loss)"""
epochs = range(1,21)
plt.plot(epochs, train_NLL, 'g', label='Training loss')
plt.title('Training loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig('train_loss.png')

# %%
"""Plot of train and test NLL (loss)"""
epochs = range(1,21)
plt.plot(epochs, test_NLL, 'b', label='validation loss')
plt.title('Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig('test_loss.png')

# %%
"""Converting predictions to python value"""
predicted = []
for i in range(len(prediction)):
    predicted.append(prediction[i].item())

# %%
from sklearn.metrics import mean_squared_error

# %%
test_data = pd.read_csv("S&P500_test.csv") #Data from 1st Jan 2018 to 31 Dec 2018
y_test = test_data['Volume']
scaler = MinMaxScaler()
y_test = array(y_test)
y_test = y_test.reshape(y_test.shape[0], 1)
y_test = scaler.fit_transform(y_test)
y_test  = series_to_supervised(test_y, n_in=TIME_STEP, n_out=2)
y_test = y_test.values
y_test = y_test[:, -1:]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
len(y_test)
# Out:
# 194

# %%
for batch_idx, (data, b_y) in enumerate(train_loader):
    print(data.size(), b_y.size())
    break
train_loader = torch.utils.data.DataLoader(datasets.MNIST('data', train=True, download=True,transform=transforms.ToTensor()),batch_size=batch_size, shuffle=True)
for batch_idx, (data, b_y) in enumerate(train_loader):
    print(data.size(), b_y.size())
    break

# %%
for i, (data, _) in enumerate(test_loader):
    print(data.size(), _.size())
    break
test_loader = torch.utils.data.DataLoader(datasets.MNIST('data', train=False, 
                                                         transform=transforms.ToTensor()),batch_size=1000, 
                                          shuffle=True)
for i, (data, _) in enumerate(test_loader):
    print(data.size(), _.size())
    break

# %%
t = torch.rand(1, 128, 1)
t = t[-1, :, :]
print(t.size())
print(t)
# Out:
# torch.Size([128, 1])
# tensor([[0.6397],
#         [0.0298],
#         [0.8449],
#         [0.5720],
#         [0.6432],
#         [0.9019],
#         [0.2763],
#         [0.1102],
#         [0.9283],
#         [0.0893],
#         [0.0661],
#         [0.3583],
#         [0.6368],
#         [0.3135],
#         [0.1607],
#         [0.9967],
#         [0.7463],
#         [0.7010],
#         [0.7298],
#         [0.7175],
#         [0.3116],
#         [0.6796],
#         [0.9794],
#         [0.3878],
#         [0.9240],
#         [0.2409],
#         [0.3587],
#         [0.2676],
#         [0.7480],
#         [0.5804],
#         [0.3924],
#         [0.4838],
#         [0.5954],
#         [0.1991],
#         [0.4294],
#         [0.8762],
#         [0.6226],
#         [0.1010],
#         [0.9106],
#         [0.3699],
#         [0.6721],
#         [0.2570],
#         [0.6619],
#         [0.4265],
#         [0.9680],
#         [0.0919],
#         [0.5341],
#         [0.6802],
#         [0.2662],
#         [0.8802],
#         [0.3855],
#         [0.4835],
#         [0.3770],
#         [0.6056],
#         [0.6292],
#         [0.9661],
#         [0.3175],
#         [0.2093],
#         [0.8058],
#         [0.5286],
#         [0.1649],
#         [0.6769],
#         [0.1005],
#         [0.4732],
#         [0.1770],
#         [0.9182],
#         [0.9212],
#         [0.9819],
#         [0.5675],
#         [0.9713],
#         [0.7668],
#         [0.8930],
#         [0.8102],
#         [0.5944],
#         [0.2517],
#         [0.9419],
#         [0.7440],
#         [0.0075],
#         [0.0294],
#         [0.4674],
#         [0.5065],
#         [0.9046],
#         [0.9242],
#         [0.0652],
#         [0.6563],
#         [0.4575],
#         [0.4541],
#         [0.4814],
#         [0.8039],
#         [0.8935],
#         [0.7541],
#         [0.1363],
#         [0.6981],
#         [0.6361],
#         [0.0258],
#         [0.9530],
#         [0.7268],
#         [0.2875],
#         [0.5935],
#         [0.3048],
#         [0.9548],
#         [0.1094],
#         [0.8437],
#         [0.7788],
#         [0.4672],
#         [0.0352],
#         [0.2640],
#         [0.1789],
#         [0.2044],
#         [0.9702],
#         [0.7196],
#         [0.6477],
#         [0.2111],
#         [0.4588],
#         [0.7082],
#         [0.3362],
#         [0.8405],
#         [0.6638],
#         [0.7981],
#         [0.8903],
#         [0.5445],
#         [0.1340],
#         [0.6114],
#         [0.3438],
#         [0.8192],
#         [0.4420],
#         [0.5000],
#         [0.5893]])

# %%
train_data = pd.read_csv("S&P500_train.csv")

# %%
train_data = pd.read_csv("S&P500_train.csv", skiprows=2)

# %%
train_data.head()
# Out:
#           Date  Open Price  Close Price  High Price  Low Price      Volume
# 0  02-Jan-2009      902.99       931.80      934.73     899.35  4048270080
# 1  05-Jan-2009      929.17       927.45      936.63     919.53  5413910016
# 2  06-Jan-2009      931.17       934.70      943.85     927.28  5392620032
# 3  07-Jan-2009      927.45       906.65      927.45     902.37  4704940032
# 4  08-Jan-2009      905.73       909.73      910.00     896.81  4991549952

# %%
train_data.head()
# Out:
#    05-Jan-2009  929.17  927.45  936.63  919.53  5413910016
# 0  06-Jan-2009  931.17  934.70  943.85  927.28  5392620032
# 1  07-Jan-2009  927.45  906.65  927.45  902.37  4704940032
# 2  08-Jan-2009  905.73  909.73  910.00  896.81  4991549952
# 3  09-Jan-2009  909.91  890.35  911.93  888.31  4716499968
# 4  12-Jan-2009  890.40  870.26  890.40  864.32  4725049856

# %%
ser = pd.Series(['a','b','c'])

# %%
ser[:1]
# Out:
# 0    a
# dtype: object

# %%
ser.loc[:1]
# Out:
# 0    a
# 1    b
# dtype: object

# %%
x = np.linspace(0,2*np.pi,100)

# %%
plt.plot(x,np.sin(x),'r-',x,np.cos(x),'b--')
# Out:
# [<matplotlib.lines.Line2D at 0x12469c518>,
#  <matplotlib.lines.Line2D at 0x12469c7b8>]

# %%
fig, ax = plt.subplots(1)
fig.plot(x, np.sin(x),)

# %%
# Out:
# torch.Size([64, 1, 28, 28]) torch.Size([64, 1, 28, 28])
# torch.Size([1000, 1, 28, 28]) torch.Size([1000])
